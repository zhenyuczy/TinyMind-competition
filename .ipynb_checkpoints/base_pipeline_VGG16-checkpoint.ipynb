# %%
from recognition import model_utils as mu
from recognition import train_model as tm
from recognition import evaluate_model as em
from recognition import csv_utils as cu
from recognition import image_utils as iu
from recognition import data_utils as du

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # 1 选择一些必要的参数

# %%
# global variables
BATCH_SIZE = 128 # batch size
IMAGE_SIZE = 96 # image size
COLOR_MODE = 'grayscale' # color mode 
RESCALE = 1./255

# %% [markdown]
# # 2 选择训练集和验证集路径

# %%
train_path, valid_path = 'datasets/train', 'datasets/validation'

# %% [markdown]
# # 3 获取generator, 并进行数据增强

# %%
train_gen, train_generator = mu.my_generator(train_path,
                                             rescale=RESCALE,
                                             horizontal_flip=False,
                                             vertical_flip=False,
                                             width_shift_range=0.1,
                                             height_shift_range=0.1,
                                             rotation_range=10,
                                             shear_range=10.0,
                                             zoom_range=0.1,
                                             shuffle=True,
                                             batch_size=BATCH_SIZE, 
                                             color_mode=COLOR_MODE, 
                                             target_size=(IMAGE_SIZE, IMAGE_SIZE))

valid_gen, valid_generator = mu.my_generator(valid_path,
                                             rescale=RESCALE,
                                             shuffle=True,
                                             batch_size=BATCH_SIZE, 
                                             color_mode=COLOR_MODE, 
                                             target_size=(IMAGE_SIZE, IMAGE_SIZE))

print('Writing the class_indices into csv file.')
cu.write_list_or_dict_into_csv(train_generator.class_indices, csv_path='class_indices.csv')
print('OK!')
# Out:
# Found 35987 images belonging to 100 classes.
# Found 4000 images belonging to 100 classes.
# Writing the class_indices into csv file.
# OK!

# %% [markdown]
# # 4 可视化数据增强的效果

# %%
image_path = 'visualize.jpg'

# %% [markdown]
# ## 4.1 训练集数据增强

# %%
iu.show_image_by_keras_augmentation(train_gen, 
                                    image_path, 
                                    target_size=(224, 224), 
                                    visualizes_number=10)

# %% [markdown]
# ## 4.2 验证集数据增强

# %%
iu.show_image_by_keras_augmentation(valid_gen, 
                                    image_path, 
                                    target_size=(224, 224), 
                                    visualizes_number=10)

# %% [markdown]
# # 5 利用VGG16训练

# %% [markdown]
# ## 5.1 构建模型

# %%
from keras.applications.vgg16 import VGG16
from keras.layers import BatchNormalization, Activation, Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, LeakyReLU, PReLU
from keras.models import Model
from keras.regularizers import l2


def build_model_based_on_vgg16(out_dims, 
                               base_weights=None, 
                               input_shape=(224, 224, 3), 
                               weights=None):
    """Build our model based on VGG16.
    
    Inputs:
       - out_dims: An integer, number of classes.
       - base_weights: the weights of the original VGG16.
       - input_shape: A tuple, shape of the input.
       - weights: The weights of model built based on VGG16.
      
    Return:
       - model: The model built based on VGG16.
    """
    vgg16_base_model = VGG16(weights=base_weights, 
                             include_top=False, 
                             input_shape=input_shape)
    x = vgg16_base_model.output
    x = Flatten()(x)

    x = Dense(2048)(x)
    x = BatchNormalization()(x)
    x = PReLU()(x)
    x = Dropout(0.6)(x)
    
    x = Dense(512)(x)
    x = BatchNormalization()(x)
    x = PReLU()(x)
    x = Dropout(0.6)(x)
    
    x = Dense(out_dims, kernel_regularizer=l2(0.01))(x)
    x = Activation('softmax')(x)
    model = Model(inputs=vgg16_base_model.input, outputs=x)
    
    if weights:
        model.load_weights(weights, by_name=True)

    return model

mu.clear_session()

channels = mu.get_channels(COLOR_MODE)
if channels is 1:
    base_weights = None
else:
    base_weights = 'imagenet'
    
model = build_model_based_on_vgg16(100, 
                                   base_weights=base_weights, 
                                   input_shape=(IMAGE_SIZE, IMAGE_SIZE, channels), 
                                   weights=None)

for index, layer in enumerate(model.layers):
    print(index, layer.name)
    
print('\n The architecture of the model:')
model.summary()
# Out:
# 0 input_1
# 1 block1_conv1
# 2 block1_conv2
# 3 block1_pool
# 4 block2_conv1
# 5 block2_conv2
# 6 block2_pool
# 7 block3_conv1
# 8 block3_conv2
# 9 block3_conv3
# 10 block3_pool
# 11 block4_conv1
# 12 block4_conv2
# 13 block4_conv3
# 14 block4_pool
# 15 block5_conv1
# 16 block5_conv2
# 17 block5_conv3
# 18 block5_pool
# 19 flatten_1
# 20 dense_1
# 21 batch_normalization_1
# 22 p_re_lu_1
# 23 dropout_1
# 24 dense_2
# 25 batch_normalization_2
# 26 p_re_lu_2
# 27 dropout_2
# 28 dense_3
# 29 activation_1
#
#  The architecture of the model:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 96, 96, 1)         0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 96, 96, 64)        640
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 96, 96, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 48, 48, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 48, 48, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 48, 48, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 24, 24, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 24, 24, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 24, 24, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 24, 24, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 12, 12, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 12, 12, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 6, 6, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 3, 3, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2048)              9439232
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 2048)              8192
# _________________________________________________________________
# p_re_lu_1 (PReLU)            (None, 2048)              2048
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 512)               2048
# _________________________________________________________________
# p_re_lu_2 (PReLU)            (None, 512)               512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 100)               51300
# _________________________________________________________________
# activation_1 (Activation)    (None, 100)               0
# =================================================================
# Total params: 25,265,956
# Trainable params: 25,260,836
# Non-trainable params: 5,120
# _________________________________________________________________

# %% [markdown]
# ## 5.2 冻结网络

# %%
freeze_range = range(0, 0)
model = mu.freeze_layers(model, freeze_range)
mu.count_parameters(model)
# Out:
# Total params: 25,265,956
# Trainable params: 25,260,836
# Non-trainable params: 5,120

# %% [markdown]
# ## 5.3 训练网络

# %%
LEARNING_RATE = 0.001
DECAY = 0
EPOCHS = 10

model_path = 'models/VGG16/model.h5'
history = tm.train_model(model,
                         train_generator, 
                         valid_generator,
                         model_path=model_path,
                         print_lr=False,
                         automatic_reduction=True,
                         patience=4,
                         reduce_factor=0.1,
                         reduce_time=6,
                         reduce_monitor='val_acc',
                         save_best='val_acc',
                         batch_size=BATCH_SIZE,
                         learning_rate=LEARNING_RATE,
                         decay=DECAY,
                         epochs=EPOCHS)
# Out:
# Epoch 1/10
# 282/282 [==============================] - 177s 629ms/step - loss: 5.5190 - acc: 0.0214 - val_loss: 4.7866 - val_acc: 0.0382
# Epoch 2/10
# 282/282 [==============================] - 170s 602ms/step - loss: 4.1406 - acc: 0.1002 - val_loss: 6.9898 - val_acc: 0.0132
# Epoch 3/10
# 282/282 [==============================] - 170s 602ms/step - loss: 3.6402 - acc: 0.1828 - val_loss: 4.2275 - val_acc: 0.0953
# Epoch 4/10
# 282/282 [==============================] - 170s 603ms/step - loss: 2.9557 - acc: 0.3396 - val_loss: 3.6493 - val_acc: 0.1830
# Epoch 5/10
# 282/282 [==============================] - 171s 605ms/step - loss: 2.3563 - acc: 0.4884 - val_loss: 1.9246 - val_acc: 0.6232
# Epoch 6/10
# 282/282 [==============================] - 172s 608ms/step - loss: 1.9638 - acc: 0.5861 - val_loss: 1.8404 - val_acc: 0.6422
# Epoch 7/10
# 282/282 [==============================] - 171s 607ms/step - loss: 1.6901 - acc: 0.6523 - val_loss: 1.4263 - val_acc: 0.7275
# Epoch 8/10
# 282/282 [==============================] - 171s 605ms/step - loss: 1.4616 - acc: 0.7077 - val_loss: 1.2396 - val_acc: 0.7650
# Epoch 9/10
# 282/282 [==============================] - 170s 604ms/step - loss: 1.2915 - acc: 0.7442 - val_loss: 1.0873 - val_acc: 0.8010
# Epoch 10/10
# 282/282 [==============================] - 170s 604ms/step - loss: 1.1497 - acc: 0.7785 - val_loss: 0.9174 - val_acc: 0.8410

# %% [markdown]
# ## 5.4 记录模型的信息，并写入csv文件

# %%
model_info = {}
model_info['batch_size'] = BATCH_SIZE
model_info['color_mode'] = COLOR_MODE
model_info['image_size'] = IMAGE_SIZE
model_info['rescale'] = RESCALE
model_info['algorithm'] = None
cu.write_list_or_dict_into_csv(model_info, csv_path='models/VGG16/model.csv')
print('OK!')
# Out:
# OK!

# %% [markdown]
# ## 5.5 绘制历史曲线

# %%
mu.draw_plot(history)

# %% [markdown]
# # 6 评估网络性能

# %% [markdown]
# ## 6.1 载入模型以及模型的非权值参数

# %%
model, model_info = mu.load_my_model('models/VGG16/model')

batch_size = int(model_info['batch_size'])
rescale = float(model_info['rescale'])
image_size = int(model_info['image_size'])
color_mode = model_info['color_mode']
algorithm = model_info['algorithm']

print('Model loaded successfully!')
# Out:
# Model loaded successfully!

# %% [markdown]
# ## 6.2 获取class_indices

# %%
class_indices = cu.get_class_indices('class_indices.csv')
print(class_indices)
# Out:
# {'且': 0, '世': 1, '东': 2, '九': 3, '亭': 4, '今': 5, '从': 6, '令': 7, '作': 8, '使': 9, '侯': 10, '元': 11, '光': 12, '利': 13, '印': 14, '去': 15, '受': 16, '右': 17, '司': 18, '合': 19, '名': 20, '周': 21, '命': 22, '和': 23, '唯': 24, '堂': 25, '士': 26, '多': 27, '夜': 28, '奉': 29, '女': 30, '好': 31, '始': 32, '字': 33, '孝': 34, '守': 35, '宗': 36, '官': 37, '定': 38, '宜': 39, '室': 40, '家': 41, '寒': 42, '左': 43, '常': 44, '建': 45, '徐': 46, '御': 47, '必': 48, '思': 49, '意': 50, '我': 51, '敬': 52, '新': 53, '易': 54, '春': 55, '更': 56, '朝': 57, '李': 58, '来': 59, '林': 60, '正': 61, '武': 62, '氏': 63, '永': 64, '流': 65, '海': 66, '深': 67, '清': 68, '游': 69, '父': 70, '物': 71, '玉': 72, '用': 73, '申': 74, '白': 75, '皇': 76, '益': 77, '福': 78, '秋': 79, '立': 80, '章': 81, '老': 82, '臣': 83, '良': 84, '莫': 85, '虎': 86, '衣': 87, '西': 88, '起': 89, '足': 90, '身': 91, '通': 92, '遂': 93, '重': 94, '陵': 95, '雨': 96, '高': 97, '黄': 98, '鼎': 99}

# %% [markdown]
# ## 6.3 评估网络模型准确度

# %% [markdown]
# ### 6.3.1 选择评估数据集路径

# %%
evaluate_path = 'datasets/validation'

# %% [markdown]
# ### 6.3.2 对数据集不使用数据增强

# %%
evaluate_gen, evaluate_generator = mu.my_generator(evaluate_path,
                                                   shuffle=False,
                                                   rescale=rescale, 
                                                   batch_size=batch_size, 
                                                   target_size=(image_size, image_size), 
                                                   color_mode=color_mode)

prediction = em.predict_without_augmentation(model, evaluate_generator)
output = {}
for k in [1, 5]:
    output[str(k)] = em.evaluate_topk_accuracy_by_single_generator(evaluate_generator, 
                                                                   class_indices,
                                                                   prediction=prediction, 
                                                                   k=k)
# Out:
# Found 4000 images belonging to 100 classes.
# Top-1 accuracy: 84.10%
# Top-5 accuracy: 94.75%

# %% [markdown]
# ### 6.3.3 自己实现对数据集使用数据增强
# - 对每张图像进行左上、左下、右上、右下、中心以及左旋10°右旋10°

# %%
evaluate_gen, evaluate_generator = mu.my_generator(evaluate_path,
                                                   shuffle=False,
                                                   rescale=rescale,
                                                   batch_size=batch_size,
                                                   target_size=(image_size, image_size), 
                                                   color_mode=color_mode)
# Out:
# Found 4000 images belonging to 100 classes.

# %%
# 查看图像增强效果
prediction = em.predict_by_my_augmentation(model,
                                           evaluate_path,
                                           evaluate_generator, 
                                           batch_process=32, 
                                           num_classes=100,
                                           show_first_fig=True,
                                           rescale=rescale,
                                           color_mode=color_mode, 
                                           target_size=(image_size, image_size))

# %%
prediction = em.predict_by_my_augmentation(model,
                                           evaluate_path,
                                           evaluate_generator, 
                                           batch_process=32, 
                                           num_classes=100,
                                           show_first_fig=False,
                                           rescale=rescale,
                                           color_mode=color_mode, 
                                           target_size=(image_size, image_size))
output = {}
for k in [1, 5]:
    output[str(k)] = em.evaluate_topk_accuracy_by_single_generator(evaluate_generator, 
                                                                   class_indices,
                                                                   prediction=prediction, 
                                                                   k=k)
# Out:
# Top-1 accuracy: 85.12%
# Top-5 accuracy: 94.85%

# %% [markdown]
# ### 6.3.4 通过Keras API对验证集使用数据增强
# - 对每张图像选择若干张增强后的图像进行预测

# %%
horizontal_flip = False
vertical_flip = False
width_shift_range = 0.1
height_shift_range = 0.1
rotation_range = 10
shear_range = 10.0
zoom_range = 0.1
channel_shift_range = 0.0
shuffle = False
                                
evaluate_gen, evaluate_generator = mu.my_generator(evaluate_path, 
                                                   rescale=rescale,
                                                   horizontal_flip=horizontal_flip,
                                                   vertical_flip=vertical_flip,
                                                   width_shift_range=width_shift_range,
                                                   height_shift_range=height_shift_range,
                                                   rotation_range=rotation_range,
                                                   shear_range=shear_range,
                                                   zoom_range=zoom_range,
                                                   channel_shift_range=channel_shift_range,
                                                   shuffle=shuffle,
                                                   batch_size=batch_size, 
                                                   color_mode=color_mode, 
                                                   target_size=(image_size, image_size))
# Out:
# Found 4000 images belonging to 100 classes.

# %%
# 查看图像增强效果
prediction = em.predict_by_keras_augmentation(model,
                                              evaluate_path,
                                              evaluate_gen,
                                              evaluate_generator, 
                                              batch_process=32, 
                                              augment_size=10,
                                              num_classes=100,
                                              show_first_fig=True,
                                              color_mode=color_mode, 
                                              target_size=(image_size, image_size))

# %%
augment_size = 6
prediction = em.predict_by_keras_augmentation(model,
                                              evaluate_path,
                                              evaluate_gen,
                                              evaluate_generator, 
                                              batch_process=32, 
                                              augment_size=augment_size,
                                              num_classes=100,
                                              show_first_fig=False,
                                              color_mode=color_mode, 
                                              target_size=(image_size, image_size))
output = {}
for k in [1, 5]:
    output[str(k)] = em.evaluate_topk_accuracy_by_single_generator(evaluate_generator, 
                                                                   class_indices,
                                                                   prediction=prediction, 
                                                                   k=k)
# Out:
# Top-1 accuracy: 83.95%
# Top-5 accuracy: 94.70%

# %% [markdown]
# ## 6.4 查看错误信息

# %%
correct_number, total_number, topk_indices, topk_classes, wrong_info = output[str(5)]
for info in wrong_info:
    print(info)
# Out:
# {'filename': '9d73098ba76ef909cc64ac99161735b9e6d4d68d.jpg', 'correct': '且', 'predict': ['朝', '游', '御', '起', '敬']}
# {'filename': '0a1c698fbf705a78466ba3c5fb81525b5b56074a.jpg', 'correct': '世', 'predict': ['女', '老', '申', '易', '多']}
# {'filename': '28c051c6c80c5f52136b3f5330f3e93d104a99b6.jpg', 'correct': '世', 'predict': ['御', '我', '林', '物', '利']}
# {'filename': '2bc30abd59d981591a8e21bc61594eaaf15da2a1.jpg', 'correct': '世', 'predict': ['黄', '常', '受', '游', '孝']}
# {'filename': '5576738f26bf69ed7dc44c1a6390e0fe9a7b14db.jpg', 'correct': '世', 'predict': ['御', '林', '和', '利', '物']}
# {'filename': '67b2869876df3477d6cff76bb7c9418c868181f2.jpg', 'correct': '世', 'predict': ['李', '多', '女', '我', '孝']}
# {'filename': '732a8affdc3afae45821107d658a5e35a37fbc20.jpg', 'correct': '世', 'predict': ['李', '易', '女', '守', '去']}
# {'filename': '874145c419a375b84b0273c68d5ec747cb454d76.jpg', 'correct': '东', 'predict': ['字', '左', '合', '官', '去']}
# {'filename': '09854d709eb304bcce5793b925149877d4cd2b64.jpg', 'correct': '九', 'predict': ['林', '我', '朝', '物', '好']}
# {'filename': '168c3a372209b054967496fb6987954f3a450fca.jpg', 'correct': '九', 'predict': ['字', '合', '令', '去', '常']}
# {'filename': '27f5647b5dbd9ef9c24c2d5900159b5144ca250e.jpg', 'correct': '九', 'predict': ['立', '女', '世', '士', '去']}
# {'filename': '4b7a9b8bb21b72936c1257b6b95b58051ddfd714.jpg', 'correct': '九', 'predict': ['足', '立', '左', '氏', '多']}
# {'filename': '60a94c9fed36d5c1f765fba26b7abefc5ce6c39d.jpg', 'correct': '九', 'predict': ['父', '必', '士', '女', '世']}
# {'filename': '69721d87a5d4705a6408d4da29a970d774437e7f.jpg', 'correct': '九', 'predict': ['御', '申', '虎', '雨', '女']}
# {'filename': '6a3c1ef6a68b6cabc2ae207c9099740faf210705.jpg', 'correct': '九', 'predict': ['永', '我', '御', '从', '秋']}
# {'filename': '0207ec8b659533dc2c3fae8164fcb6e9b09b89c6.jpg', 'correct': '今', 'predict': ['用', '多', '朝', '利', '物']}
# {'filename': '0d0e248cfb4a8d9ae27823824bb0348eb43ee5a1.jpg', 'correct': '今', 'predict': ['常', '立', '合', '命', '令']}
# {'filename': '566f4d68b08af8800f403ee9c693c7a1e5db69e0.jpg', 'correct': '今', 'predict': ['黄', '寒', '常', '莫', '益']}
# {'filename': '33aba93f9ac47f24d955c8b339688264e46f0925.jpg', 'correct': '从', 'predict': ['我', '西', '新', '朝', '好']}
# {'filename': '645b3ff727bb415dc69240e78849b43432ec57d5.jpg', 'correct': '从', 'predict': ['必', '好', '利', '朝', '物']}
# {'filename': '8372ecd398b17481be2b261e793fd4b8f5884d72.jpg', 'correct': '从', 'predict': ['左', '多', '世', '立', '足']}
# {'filename': '91d6eb64ae0948a89d0d0b1c550e80e84528c7eb.jpg', 'correct': '从', 'predict': ['秋', '和', '御', '新', '利']}
# {'filename': '1f2c3d4d00a223cbb989212c7f423039afda06fc.jpg', 'correct': '令', 'predict': ['印', '御', '常', '申', '寒']}
# {'filename': '3b63827a39505fd0803a79a359d40aa85062f3d6.jpg', 'correct': '令', 'predict': ['合', '命', '立', '高', '亭']}
# {'filename': '5308209ddf152f15a7aeded2c37f7917607f0ee6.jpg', 'correct': '令', 'predict': ['通', '且', '意', '立', '宜']}
# {'filename': '5aad643f19b0255144c0271f403a2fea0e7f37e6.jpg', 'correct': '令', 'predict': ['正', '左', '去', '多', '立']}
# {'filename': '23a5e1bf8dabebc47e26ffe2b8446ee076d314cd.jpg', 'correct': '作', 'predict': ['我', '身', '朝', '永', '新']}
# {'filename': '2f380a34cd26572aff38c0e152b97864cc62bf68.jpg', 'correct': '作', 'predict': ['好', '秋', '九', '必', '始']}
# {'filename': '5840d98a4eb16dc8c4f9f592adc4869a5c142e30.jpg', 'correct': '作', 'predict': ['老', '去', '世', '武', '周']}
# {'filename': '6bf0a1087280452b98ed3ab79f2ec613149d14b2.jpg', 'correct': '作', 'predict': ['令', '世', '御', '今', '白']}
# {'filename': '07d8c51cd392e95e6da412fdb6d02cd56b3710e2.jpg', 'correct': '侯', 'predict': ['意', '寒', '福', '夜', '海']}
# {'filename': '282cf85e51eca8c40f7d729844ec4d97b4a8f611.jpg', 'correct': '侯', 'predict': ['朝', '官', '合', '左', '莫']}
# {'filename': '831929742a49cf19f4b41b144f87d402d25984bc.jpg', 'correct': '侯', 'predict': ['西', '正', '父', '白', '且']}
# {'filename': '868737153c0f4cde6fd44f47b41c3fd13cda5f1e.jpg', 'correct': '侯', 'predict': ['亭', '意', '莫', '高', '寒']}
# {'filename': '5a768546226a680eb1e85361216369c195571ebf.jpg', 'correct': '光', 'predict': ['好', '起', '印', '和', '始']}
# {'filename': '7d1f56ebaa4c5c2a1c0717b923f3a6b200b125c6.jpg', 'correct': '利', 'predict': ['新', '西', '永', '玉', '和']}
# {'filename': '0061c17cdc336fc36c9bc7f095df4667978454b0.jpg', 'correct': '印', 'predict': ['名', '和', '老', '衣', '右']}
# {'filename': '25b97880edf99721272326e66fb18747c50ba009.jpg', 'correct': '印', 'predict': ['利', '始', '朝', '老', '物']}
# {'filename': '3525dcac1ba933b844109defaaf51323fa768dbb.jpg', 'correct': '印', 'predict': ['鼎', '申', '福', '朝', '始']}
# {'filename': '36000b899f19c94f5312ef1fd18ce77425cc5379.jpg', 'correct': '印', 'predict': ['申', '堂', '士', '女', '世']}
# {'filename': '3afb684ca75102618fe8a86986133e449a2cfd8e.jpg', 'correct': '印', 'predict': ['臣', '思', '宜', '正', '且']}
# {'filename': '93c89d3a5d6935dd6a5bafddb07d577c135f767f.jpg', 'correct': '去', 'predict': ['奉', '春', '李', '老', '孝']}
# {'filename': '6d73c712450ed7c97c955768070ee4a17d3ba6d6.jpg', 'correct': '受', 'predict': ['我', '用', '世', '好', '女']}
# {'filename': '0d7742a88817f1eaea9b168dfeaf10db706e6584.jpg', 'correct': '右', 'predict': ['常', '御', '堂', '女', '老']}
# {'filename': '4ba0c7edc98f7ff813119f7a82c3b5e18fdc0ea1.jpg', 'correct': '右', 'predict': ['朝', '敬', '始', '福', '起']}
# {'filename': '6d6b84ada38b95bb3c2018ac5353816f08c3a99d.jpg', 'correct': '右', 'predict': ['官', '海', '福', '寒', '陵']}
# {'filename': '14143a468c4db09d3f7f844ba43c03c852a1e280.jpg', 'correct': '司', 'predict': ['御', '寒', '福', '新', '朝']}
# {'filename': '03869355b7980ebce3f3de98ec6e991eea00e057.jpg', 'correct': '合', 'predict': ['家', '室', '定', '官', '寒']}
# {'filename': '41e508166f9cc08f088b5add621ba663140919a6.jpg', 'correct': '合', 'predict': ['好', '始', '思', '春', '周']}
# {'filename': '8d74cf4c12f8901112aeb52314e4273fd297d726.jpg', 'correct': '合', 'predict': ['朝', '命', '福', '新', '敬']}
# {'filename': '2e5dc8810cad99935b039881a978264a15e9c0fd.jpg', 'correct': '名', 'predict': ['白', '玉', '臣', '正', '西']}
# {'filename': '65ad2c0c0fa55dd8fcab6148ee2c54a13864c563.jpg', 'correct': '名', 'predict': ['室', '福', '海', '寒', '御']}
# {'filename': '35f1682c400ebcf828d391917e48fa3067ac92c2.jpg', 'correct': '周', 'predict': ['黄', '多', '易', '物', '女']}
# {'filename': '30995f50c49f012ecb4d3c0913d9346363f4a6ae.jpg', 'correct': '命', 'predict': ['皇', '思', '寒', '足', '定']}
# {'filename': '432cb9d0117b9ca7d81762860826969135ded615.jpg', 'correct': '命', 'predict': ['章', '受', '意', '莫', '寒']}
# {'filename': '52bc47377d02d738b97540b80e63885da7717e0b.jpg', 'correct': '命', 'predict': ['黄', '莫', '重', '寒', '章']}
# {'filename': '572e196334c84008c0511abbcc32ae4cef46eb7e.jpg', 'correct': '命', 'predict': ['父', '女', '始', '氏', '好']}
# {'filename': '1e5940b41f5d03546d0c1af4b054a1d4156015bd.jpg', 'correct': '和', 'predict': ['侯', '唯', '武', '身', '氏']}
# {'filename': '63d4f9f153a12037bcc77d79cd255dd0602c9553.jpg', 'correct': '和', 'predict': ['深', '流', '虎', '东', '徐']}
# {'filename': '7ecec9d5370762b401773cb40441bb09c9569519.jpg', 'correct': '和', 'predict': ['深', '林', '福', '流', '徐']}
# {'filename': '8f73c16b0f2da6ec31e05f8fdb6a119d5d8b1add.jpg', 'correct': '和', 'predict': ['世', '春', '林', '我', '游']}
# {'filename': '0a8268d189bea71026a415593a6c03c51e6ddf91.jpg', 'correct': '唯', 'predict': ['意', '朝', '福', '和', '新']}
# {'filename': '81ab5da688fc3c0c7245b62be784d6f2bdf21f9c.jpg', 'correct': '唯', 'predict': ['意', '周', '春', '高', '合']}
# {'filename': '517beaa1be855e8af1584508a7b819905c8b7b0f.jpg', 'correct': '士', 'predict': ['从', '雨', '西', '正', '立']}
# {'filename': '6fbbba26fa6cd9f659951ec68a4282b3e26c73f1.jpg', 'correct': '士', 'predict': ['奉', '春', '黄', '东', '李']}
# {'filename': '0f67e9ba8a0bd00fe2d1d8fe365cd0ffdb816478.jpg', 'correct': '多', 'predict': ['光', '父', '身', '申', '使']}
# {'filename': '218d8da66f1bba440e9bb2d40f74cdd49383c525.jpg', 'correct': '多', 'predict': ['白', '作', '立', '朝', '从']}
# {'filename': '8bcc4866bf5029a45972d27bdba6d9cfcba38b88.jpg', 'correct': '多', 'predict': ['世', '利', '新', '西', '我']}
# {'filename': '1a56646af695a3f6e0b6bc7c65e22dd43b227d6d.jpg', 'correct': '奉', 'predict': ['利', '好', '和', '御', '物']}
# {'filename': '27b8e180ec9171974ef217b09ec62c996bf3899e.jpg', 'correct': '女', 'predict': ['氏', '和', '命', '敬', '印']}
# {'filename': '71c58799e7f9d5c48ef746c6406ecd02a6322258.jpg', 'correct': '女', 'predict': ['秋', '和', '深', '鼎', '徐']}
# {'filename': '2775fbbdd096187bd703b5512d0b498edcfad742.jpg', 'correct': '好', 'predict': ['世', '父', '作', '从', '必']}
# {'filename': '0e3be4ae7068af18047ef123bee0cf1861863ed8.jpg', 'correct': '始', 'predict': ['利', '新', '受', '朝', '寒']}
# {'filename': '201064159313e3d86d999919be9fa54cb6ae3621.jpg', 'correct': '始', 'predict': ['身', '家', '敬', '朝', '鼎']}
# {'filename': '5ec8b9531775c52e45e5c689e949e07d0c9aaa33.jpg', 'correct': '始', 'predict': ['受', '寒', '利', '新', '朝']}
# {'filename': '87c7ea58eba13ce2ca5970174a7bf4574bbf8ba8.jpg', 'correct': '始', 'predict': ['新', '秋', '和', '我', '敬']}
# {'filename': 'a2c4d9792a34c152f2da2e065bd6a601d60c4d84.jpg', 'correct': '始', 'predict': ['周', '朝', '寒', '用', '好']}
# {'filename': 'b00ece8ec5c7d1d236453cf8b6fed881bd54152c.jpg', 'correct': '始', 'predict': ['秋', '和', '利', '朝', '物']}
# {'filename': '1f24322c8a8cde1625ad697ecdaf7d9f84c2a5ce.jpg', 'correct': '守', 'predict': ['定', '家', '宜', '思', '室']}
# {'filename': '2bfa663933abe1dc93d6fba44a2a703ab2e57e76.jpg', 'correct': '守', 'predict': ['周', '女', '虎', '雨', '用']}
# {'filename': '4872fcce52593eab3559ff1374d49f91a15d6577.jpg', 'correct': '守', 'predict': ['今', '虎', '家', '命', '徐']}
# {'filename': '6252737c4762e6a27b0ba9ea005ab2a62944a787.jpg', 'correct': '守', 'predict': ['周', '女', '虎', '雨', '用']}
# {'filename': '9911f02826b7657921393c3590c367dacdf31a7e.jpg', 'correct': '守', 'predict': ['白', '西', '官', '宜', '室']}
# {'filename': '0c7f60d7cb420e93a02949a05ad03d2f11c1de22.jpg', 'correct': '宗', 'predict': ['字', '命', '多', '高', '亭']}
# {'filename': '5bf4ed2c67b93ba899672c3a904998a73fdbeba8.jpg', 'correct': '宗', 'predict': ['虎', '命', '家', '雨', '寒']}
# {'filename': '8f7ad08fbcd8f8dac92a12d2075e5d73b7b597bb.jpg', 'correct': '宗', 'predict': ['东', '奉', '遂', '字', '家']}
# {'filename': '0403fb626fd55c9ff7822ee3f069ec61d3012cb6.jpg', 'correct': '官', 'predict': ['守', '室', '用', '家', '雨']}
# {'filename': '3a9d3219e7ec0f33460b7e3d3fcec4373ad68a94.jpg', 'correct': '官', 'predict': ['司', '氏', '令', '父', '今']}
# {'filename': '129ff6e3afef07513bb1e5b57958e9442eaa4d0f.jpg', 'correct': '定', 'predict': ['思', '家', '字', '室', '寒']}
# {'filename': '2a612c97298e1a59d1fc6ab8554e7814a3783e70.jpg', 'correct': '定', 'predict': ['御', '命', '海', '官', '合']}
# {'filename': '359a3037f0084e6663b59fdb339a1b1065682e72.jpg', 'correct': '定', 'predict': ['衣', '今', '白', '氏', '正']}
# {'filename': '603c0a92e7dc7977f8057ff003eaf9333ddfbf90.jpg', 'correct': '定', 'predict': ['今', '家', '字', '命', '宗']}
# {'filename': '81475191551966f9e902929ed2ccea5819ff0f9a.jpg', 'correct': '定', 'predict': ['遂', '武', '春', '去', '老']}
# {'filename': '87e4273acfa70082a1b4ffad2c11a321e239e1f8.jpg', 'correct': '定', 'predict': ['秋', '利', '必', '女', '我']}
# {'filename': '8943ae7d9b9415e52659c763ff4c6038de76b656.jpg', 'correct': '定', 'predict': ['多', '思', '命', '印', '寒']}
# {'filename': '1ca5c110ffab959695f71fa1ded10433b1bbeec3.jpg', 'correct': '宜', 'predict': ['守', '今', '父', '且', '白']}
# {'filename': '71606aa71ef64e5c9591e7edb8d75b8d58503cc8.jpg', 'correct': '宜', 'predict': ['朝', '守', '易', '家', '多']}
# {'filename': '7c892565fab5dada0ae8718183978bde70c40d5c.jpg', 'correct': '宜', 'predict': ['徐', '益', '合', '遂', '福']}
# {'filename': '7ca5ed2c786a469b36ad1080dcf6e820be1b7b1c.jpg', 'correct': '宜', 'predict': ['莫', '益', '寒', '命', '意']}
# {'filename': '0d936574994d83663338cd3c650fd99f0bc9aaf4.jpg', 'correct': '室', 'predict': ['命', '福', '通', '遂', '御']}
# {'filename': '5d3e667e2caeeb83ca39d3a448a78afbb51fd4d4.jpg', 'correct': '室', 'predict': ['春', '玉', '高', '重', '意']}
# {'filename': '1575db684beeebf567ebb3d5b0b651e6dfb66695.jpg', 'correct': '家', 'predict': ['女', '去', '我', '李', '奉']}
# {'filename': '26ac4cd9ddfe1789c7958d99ee33b9ba5cbddd6d.jpg', 'correct': '家', 'predict': ['雨', '用', '周', '室', '寒']}
# {'filename': '5cd95cb0b5f52f824348ad6688c4bf61e7b77815.jpg', 'correct': '寒', 'predict': ['良', '合', '令', '宜', '白']}
# {'filename': '1d8ceb3271a0c338e5d70d238dec61cc5822f688.jpg', 'correct': '左', 'predict': ['良', '侯', '寒', '周', '陵']}
# {'filename': '26ba797013b7edd2176916fb3704e579ab8a1509.jpg', 'correct': '左', 'predict': ['使', '建', '我', '女', '寒']}
# {'filename': '51acedbcd4ed0fb0d29f756b57dfb80630c0bf01.jpg', 'correct': '左', 'predict': ['多', '印', '益', '莫', '皇']}
# {'filename': '544297a49befde9b823537db6d26ddbd56a8ef15.jpg', 'correct': '左', 'predict': ['士', '宜', '右', '身', '司']}
# {'filename': '72ba57ed66a9fd290cc6ae4f042c37bd2866e06a.jpg', 'correct': '左', 'predict': ['意', '易', '高', '多', '名']}
# {'filename': '0925250892bb4244b514a7d19a1c044d9febec63.jpg', 'correct': '常', 'predict': ['东', '奉', '亭', '字', '章']}
# {'filename': '85a9b4acb84712e340067b33e848fc1282a822ee.jpg', 'correct': '常', 'predict': ['奉', '春', '新', '朝', '孝']}
# {'filename': '696ec5fde64a9bbc24723b41570102e88eccf41d.jpg', 'correct': '御', 'predict': ['高', '宜', '名', '福', '官']}
# {'filename': '6bc15397234af31145a030e279eb08e788396817.jpg', 'correct': '御', 'predict': ['作', '始', '九', '起', '印']}
# {'filename': '09fd02f7deba228bdaca9a9ee5b02e2540e97d4a.jpg', 'correct': '必', 'predict': ['女', '夜', '西', '御', '和']}
# {'filename': '0d89996318fd0b34d59d1f10e37aa44a8c6dbfa2.jpg', 'correct': '必', 'predict': ['去', '合', '作', '左', '今']}
# {'filename': '853ea4ec43d40db9b98bd3b69f7408cc0797a5e6.jpg', 'correct': '必', 'predict': ['游', '雨', '好', '物', '御']}
# {'filename': '9f8e9814df735ba379cd582fed787db073bc6998.jpg', 'correct': '必', 'predict': ['海', '雨', '御', '西', '物']}
# {'filename': '354093d1e483358a5b714e714e8066c72454738c.jpg', 'correct': '思', 'predict': ['多', '必', '申', '女', '受']}
# {'filename': '5421ff69c30ef066971d4ced17c0453e97455a8e.jpg', 'correct': '思', 'predict': ['室', '寒', '受', '多', '字']}
# {'filename': '024c3f751c4162998d93edcfca08693183b0253a.jpg', 'correct': '意', 'predict': ['新', '我', '多', '易', '高']}
# {'filename': '67551b70537fed51357d1454a141343b909a4354.jpg', 'correct': '敬', 'predict': ['物', '御', '朝', '新', '海']}
# {'filename': '67d449cfc5f7d3d23c9c225f601a23bf2ce40124.jpg', 'correct': '敬', 'predict': ['春', '寒', '周', '朝', '福']}
# {'filename': '76f20c6d95a74e75a20a12eab50c25244bd2be52.jpg', 'correct': '敬', 'predict': ['陵', '唯', '福', '御', '寒']}
# {'filename': '959efdc66c73e2b23d2e32207f90a3b0c8bf5cec.jpg', 'correct': '敬', 'predict': ['林', '世', '女', '好', '我']}
# {'filename': '1edbba02462f3a0930b9288b5db25b443ce2ee58.jpg', 'correct': '易', 'predict': ['受', '亭', '多', '身', '字']}
# {'filename': '6d2a8f8e84a9f6c0ef3d2a77a16aaa06cccdd11c.jpg', 'correct': '易', 'predict': ['唯', '思', '鼎', '和', '老']}
# {'filename': '38bd86e603902147b8a3257efa00f3d23b0b833d.jpg', 'correct': '春', 'predict': ['虎', '身', '易', '鼎', '命']}
# {'filename': '44c796eefb2a02098f6171e7bebda54949f66ea8.jpg', 'correct': '春', 'predict': ['字', '受', '思', '申', '皇']}
# {'filename': '62db618be8108238ffeb08d794b99df729b63a60.jpg', 'correct': '春', 'predict': ['清', '陵', '建', '虎', '奉']}
# {'filename': '642c2621db8fff5adc53ce5724b4c20c72bd0195.jpg', 'correct': '春', 'predict': ['世', '来', '武', '我', '去']}
# {'filename': '6f0699fdc2a5dbbc08d2c0ce984ec399b5ce68be.jpg', 'correct': '春', 'predict': ['世', '秋', '物', '好', '林']}
# {'filename': '4b34410b1d2f5e9c299b274652c9b443dd35d001.jpg', 'correct': '更', 'predict': ['使', '女', '家', '春', '守']}
# {'filename': '45bf2c9be0813fb17acaa40035a323c538cd6240.jpg', 'correct': '朝', 'predict': ['元', '永', '思', '足', '鼎']}
# {'filename': '18ffd482d14f9deba77624806db72701046d6d9d.jpg', 'correct': '李', 'predict': ['益', '老', '莫', '常', '意']}
# {'filename': '2880a8ababa1a72655318499de3694e3129da740.jpg', 'correct': '李', 'predict': ['立', '父', '多', '字', '身']}
# {'filename': '1ee8fb3b7be6bb70f6b303c6b77e617658027006.jpg', 'correct': '来', 'predict': ['用', '室', '深', '字', '东']}
# {'filename': '51fdf3b15a1054a4db54e77d1e77981caf7530bd.jpg', 'correct': '来', 'predict': ['奉', '海', '游', '遂', '孝']}
# {'filename': '65d9671d960738f8706a036dba57320d13115fe7.jpg', 'correct': '来', 'predict': ['武', '孝', '春', '去', '李']}
# {'filename': '0b1c43e34b9c0033ba0e52f9cf8cc0d632ad7fb8.jpg', 'correct': '林', 'predict': ['福', '新', '奉', '寒', '御']}
# {'filename': '2052b4819a33cecb079c778cbe2649d63b245307.jpg', 'correct': '正', 'predict': ['九', '白', '足', '父', '今']}
# {'filename': '20c15ea0458766ee727d1ecdfb92d20e1be17e9c.jpg', 'correct': '正', 'predict': ['申', '易', '白', '多', '西']}
# {'filename': '2b293fc1d470c1bb71329e5c5482589a2daa6ce0.jpg', 'correct': '正', 'predict': ['游', '福', '朝', '永', '始']}
# {'filename': '5473753effed942860f0534bcd6283869e786d1a.jpg', 'correct': '正', 'predict': ['雨', '重', '玉', '西', '多']}
# {'filename': '5acb94eacfaa5eb2dc9e7c45c10461d46e972df7.jpg', 'correct': '正', 'predict': ['印', '命', '女', '西', '好']}
# {'filename': '5f50f98638eb04fb989ebe854cefb966c6bacbb2.jpg', 'correct': '正', 'predict': ['定', '臣', '通', '思', '西']}
# {'filename': '65088216acfd509289843cbd75db91df794ede18.jpg', 'correct': '正', 'predict': ['西', '司', '受', '周', '思']}
# {'filename': '182e012d3762b9fd2844885c5be462fa64334c5e.jpg', 'correct': '武', 'predict': ['益', '物', '御', '福', '遂']}
# {'filename': '1641c3a9e68631ee99f413d61f3b2f04e64cbbe4.jpg', 'correct': '氏', 'predict': ['秋', '思', '莫', '和', '鼎']}
# {'filename': '0a2a76f1cc7ed831eb5ecd0af0da01abfe95c280.jpg', 'correct': '永', 'predict': ['好', '春', '朝', '寒', '御']}
# {'filename': '1636e55045e665355105a637e37231761805c795.jpg', 'correct': '永', 'predict': ['敬', '朝', '游', '起', '御']}
# {'filename': '0069a8faae9dd9e184e447ddf13c0d2e2602617e.jpg', 'correct': '流', 'predict': ['黄', '虎', '徐', '易', '我']}
# {'filename': '785319ef8be4aa210be0e4b26a203d390f3d92bd.jpg', 'correct': '深', 'predict': ['通', '御', '好', '海', '游']}
# {'filename': '56ca3a5f3cfa42d1ab6328e5f2395e68592fdaf5.jpg', 'correct': '清', 'predict': ['陵', '侯', '虎', '春', '周']}
# {'filename': '127a5842466e179eeddb53617ee5b58abacec823.jpg', 'correct': '父', 'predict': ['印', '好', '受', '世', '女']}
# {'filename': '80af4d8a95297b6d223aee3eef587ce7a375ce35.jpg', 'correct': '父', 'predict': ['元', '今', '九', '从', '左']}
# {'filename': '02152df4372f30223ca103768119ab76e1adaf73.jpg', 'correct': '玉', 'predict': ['思', '莫', '鼎', '且', '身']}
# {'filename': '803916b5aefb948b70c89faa7b1721b83407cc4c.jpg', 'correct': '玉', 'predict': ['易', '父', '我', '身', '女']}
# {'filename': '8c40fc15c1d3e844df9fc670dd9c9070a31002b0.jpg', 'correct': '玉', 'predict': ['好', '多', '易', '世', '女']}
# {'filename': '1488b010500677453fa1aeae50afdf3de047751e.jpg', 'correct': '用', 'predict': ['黄', '来', '林', '老', '我']}
# {'filename': '1de8c8f1ace6597110933bdfc70c0af7fc01873a.jpg', 'correct': '申', 'predict': ['令', '名', '今', '去', '合']}
# {'filename': '37d1f56c0a026dbc567c3b64c1fcdbd4fe402532.jpg', 'correct': '申', 'predict': ['始', '朝', '福', '通', '唯']}
# {'filename': 'a09a8646a7d9a9a32ca16a719384124d381bfa4a.jpg', 'correct': '申', 'predict': ['使', '身', '且', '鼎', '良']}
# {'filename': '02c821376c2ad45a8f4ebb69530725284a243035.jpg', 'correct': '白', 'predict': ['衣', '世', '和', '多', '西']}
# {'filename': '045ee541ba34686004adb9ff6d9e61610bb711d6.jpg', 'correct': '白', 'predict': ['家', '周', '春', '身', '遂']}
# {'filename': '1c5e1f5ff8ff826f15a720154fa815b4842b22ca.jpg', 'correct': '白', 'predict': ['申', '福', '雨', '新', '朝']}
# {'filename': '558e5a8f1f63b0571b78976df3a7ecee5817a827.jpg', 'correct': '白', 'predict': ['雨', '物', '始', '福', '朝']}
# {'filename': '6b0324131e5badbbccd36d2e99e549427277b33e.jpg', 'correct': '白', 'predict': ['官', '司', '家', '合', '守']}
# {'filename': '03211af74a2baf25888e60983e1e43dad15a6d73.jpg', 'correct': '皇', 'predict': ['左', '氏', '必', '父', '今']}
# {'filename': '02a1cb3dfc0360abc4885a47a96adc3b6e54f7f4.jpg', 'correct': '福', 'predict': ['用', '女', '奉', '申', '西']}
# {'filename': '3e97aebec0eaeea50c28b08e08da7f6566b044b9.jpg', 'correct': '福', 'predict': ['陵', '敬', '受', '孝', '春']}
# {'filename': '55bb1de52fd3ea9bad41f8bd97264ea63dcd0fbb.jpg', 'correct': '福', 'predict': ['通', '亭', '高', '易', '西']}
# {'filename': '857fb6d4726f98ea962c699be70c7564a20f4b17.jpg', 'correct': '福', 'predict': ['老', '奉', '更', '来', '春']}
# {'filename': '2b937dd56e29e6cf0da463a6c248223c26f07abe.jpg', 'correct': '秋', 'predict': ['鼎', '奉', '游', '深', '徐']}
# {'filename': '31025cd5c4c2d2552ce3fa10a1f616124958b586.jpg', 'correct': '秋', 'predict': ['和', '新', '御', '春', '敬']}
# {'filename': '68f8473debb45d81e587a4a389fc66f5d3268a63.jpg', 'correct': '秋', 'predict': ['重', '通', '黄', '寒', '海']}
# {'filename': '5101841aaeca303e0e3639f1fc1656400cfa7904.jpg', 'correct': '立', 'predict': ['好', '御', '始', '起', '游']}
# {'filename': '2de011dc80e5cdb64dec8343ff065db28b1197ec.jpg', 'correct': '章', 'predict': ['雨', '室', '周', '官', '寒']}
# {'filename': '3a8fa5e6c65b011e4b1622c9060813585d5078cf.jpg', 'correct': '章', 'predict': ['重', '寒', '雨', '建', '周']}
# {'filename': '80c640ab5fa127576ffeda2006f2b9a65e6f14aa.jpg', 'correct': '老', 'predict': ['士', '左', '立', '去', '世']}
# {'filename': '140b91defa12378c39e6d8b4d7fa1ee73391619e.jpg', 'correct': '臣', 'predict': ['女', '世', '思', '且', '西']}
# {'filename': '3870f055caf43c1668d084faebf227c2de31b941.jpg', 'correct': '臣', 'predict': ['身', '西', '司', '申', '白']}
# {'filename': '5f1a546fafbfbae1f243176be9e1ecdacd177c8a.jpg', 'correct': '臣', 'predict': ['元', '去', '衣', '正', '玉']}
# {'filename': '9b7f01fb4d4223454c73dc80697a1e274cea5b3e.jpg', 'correct': '臣', 'predict': ['通', '申', '用', '更', '思']}
# {'filename': '102a1e28e9f520245e6681f46023199fa3ab948e.jpg', 'correct': '良', 'predict': ['更', '且', '身', '亭', '高']}
# {'filename': '21705c9d98ab3bd2a3cb0b68974fb38f593669c5.jpg', 'correct': '良', 'predict': ['孝', '春', '亭', '高', '合']}
# {'filename': '7610441f5ed24f90d85735be2b7f5488d8b506cb.jpg', 'correct': '良', 'predict': ['老', '足', '莫', '思', '皇']}
# {'filename': '8f235e101edfc4b21ef0ad2f13e357c61c5d0c37.jpg', 'correct': '良', 'predict': ['益', '老', '莫', '受', '意']}
# {'filename': '22f232b5bd0f2d994c0248386bda32e0884951d2.jpg', 'correct': '莫', 'predict': ['周', '春', '虎', '御', '寒']}
# {'filename': '1b434c389ec8d33a2a47d4c8eda4445f4f3c88f7.jpg', 'correct': '虎', 'predict': ['申', '老', '用', '孝', '周']}
# {'filename': '279b526b6a911e6895b36830392f8b3fd7352f3b.jpg', 'correct': '虎', 'predict': ['起', '建', '御', '寒', '老']}
# {'filename': '56687e7e806dba777cddb0aab9aa102d6f744441.jpg', 'correct': '虎', 'predict': ['我', '司', '受', '永', '身']}
# {'filename': '7fe5e332d30514fb005e4a37eb7ec3c7da28d1ca.jpg', 'correct': '虎', 'predict': ['女', '受', '更', '我', '身']}
# {'filename': '970c7fb9bbb62ef1820f6e39b9d39e98f6e18266.jpg', 'correct': '虎', 'predict': ['女', '物', '雨', '西', '御']}
# {'filename': '988e740788001e02f5b249415d763dd04e8fb669.jpg', 'correct': '虎', 'predict': ['奉', '遂', '黄', '寒', '春']}
# {'filename': '76583890f07fe768ccb0c944acf2c61e0ed0e43e.jpg', 'correct': '衣', 'predict': ['流', '御', '必', '世', '海']}
# {'filename': '7b55509eb85f1c0df0e4b1d72d4ff1bd05519865.jpg', 'correct': '衣', 'predict': ['游', '正', '立', '士', '世']}
# {'filename': '191d0902d2fa4c19a52c4c7d3d9afe69e6f2a34f.jpg', 'correct': '西', 'predict': ['家', '宗', '思', '益', '多']}
# {'filename': '1deb874998e831a39ba35c52e4cd3b34e442d385.jpg', 'correct': '西', 'predict': ['命', '好', '黄', '我', '女']}
# {'filename': '946a6b02718bac68817600cae2f6e23fa9bc8664.jpg', 'correct': '起', 'predict': ['好', '奉', '陵', '林', '我']}
# {'filename': '00ebac7eed491fbaa01c8afa0d9f499f623c7611.jpg', 'correct': '足', 'predict': ['且', '女', '去', '今', '立']}
# {'filename': '13897c8b5db5e60bcf70b67c587ab09e0e8ae7c8.jpg', 'correct': '身', 'predict': ['始', '莫', '皇', '易', '鼎']}
# {'filename': '585337f15d80bd97b2a8ad671a4c627ebe7f6682.jpg', 'correct': '身', 'predict': ['白', '申', '多', '西', '用']}
# {'filename': '982dadc62d487beccb70810484d7752ae07ecd8a.jpg', 'correct': '身', 'predict': ['去', '女', '名', '多', '易']}
# {'filename': '0bd5249ddb5d2067f9258159b4b84e1ba65c570b.jpg', 'correct': '通', 'predict': ['作', '从', '游', '世', '御']}
# {'filename': '1e7f5619e2c43d10cc6adb905695c14f3e6fb28e.jpg', 'correct': '遂', 'predict': ['良', '西', '周', '氏', '臣']}
# {'filename': '223b61745cd65bfa367acc41fb28c384ab1d94d3.jpg', 'correct': '遂', 'predict': ['合', '海', '今', '左', '去']}
# {'filename': '78a1843fcaf98cb220c00b9859206d1a1010d8e5.jpg', 'correct': '遂', 'predict': ['臣', '御', '海', '家', '西']}
# {'filename': '1ae6ee4783fb45071db39c0fe6625caeca9cb169.jpg', 'correct': '陵', 'predict': ['游', '物', '朝', '好', '始']}
# {'filename': '0dd2498ee4cc9b09ccd5fdd0cde7c02657cbaf24.jpg', 'correct': '高', 'predict': ['家', '命', '合', '遂', '西']}
# {'filename': '5619eaf40665bd11eea7602709e50bd061ee4c91.jpg', 'correct': '高', 'predict': ['物', '海', '清', '朝', '福']}
# {'filename': '20f53cb680b055aa6cc38ddc6ce3ee7aa54397fe.jpg', 'correct': '黄', 'predict': ['章', '侯', '奉', '虎', '徐']}
# {'filename': '2ce91581c103d3fa52b9ac40bb4c1980ee4a6d69.jpg', 'correct': '鼎', 'predict': ['光', '常', '受', '黄', '莫']}

# %% [markdown]
# ## 6.5 可视化错误图像

# %%
# 选择前十张查看 
iu.show_images_in_wrong_info(wrong_info, evaluate_path, visualizes_number=10)

# %% [markdown]
# ## 6.6 选择最优的预测算法
# - `no_aug`: 不使用数据增强
# - `my_aug`: 使用自己的数据增强方法
# - `ke_aug`: 使用Keras API的数据增强方法

# %%
algorithm = 'ke_aug'
model_info['algorithm'] = algorithm
if algorithm == 'ke_aug':
    model_info['horizontal_flip'] = horizontal_flip
    model_info['vertical_flip'] = vertical_flip
    model_info['width_shift_range'] = width_shift_range
    model_info['height_shift_range'] = height_shift_range
    model_info['rotation_range'] = rotation_range
    model_info['shear_range'] = shear_range
    model_info['zoom_range'] = zoom_range
    model_info['channel_shift_range'] = channel_shift_range
    model_info['shuffle'] = shuffle
    model_info['augment_size'] = augment_size
    
cu.write_list_or_dict_into_csv(model_info, csv_path='models/VGG16/model.csv')

# %% [markdown]
# # 7 预测测试集

# %% [markdown]
# ## 7.1 载入模型和非权值参数

# %%
model, model_info = mu.load_my_model('models/VGG16/model')

batch_size = int(model_info['batch_size'])
rescale = float(model_info['rescale'])
image_size = int(model_info['image_size'])
color_mode = model_info['color_mode']
algorithm = model_info['algorithm']
augment_size = None

if algorithm == 'ke_aug':
    horizontal_flip = model_info['horizontal_flip']=='True'
    vertical_flip = model_info['vertical_flip']=='True'
    width_shift_range = float(model_info['width_shift_range'])
    height_shift_range = float(model_info['height_shift_range'])
    rotation_range = int(model_info['rotation_range'])
    shear_range = float(model_info['shear_range'])
    zoom_range = float(model_info['zoom_range'])
    channel_shift_range = float(model_info['channel_shift_range'])
    shuffle = model_info['shuffle']=='True'
    augment_size = int(model_info['augment_size'])

print('Model loaded successfully!')
# Out:
# Model loaded successfully!

# %% [markdown]
# ## 7.2 选择k值、测试集的路径以及预测算法

# %%
k = 5
test_path = 'datasets/validation'
if algorithm not in ['no_aug', 'my_aug', 'ke_aug']:
        raise ValueError('The algorithm must be one of \'no_aug\',\'my_aug\',\'ke_aug\'.')

# %% [markdown]
# ## 7.3 获取top-k预测值

# %%
if algorithm == 'no_aug' or algorithm == 'my_aug':
    test_gen, test_generator = mu.my_generator(test_path,
                                               shuffle=False,
                                               rescale=rescale, 
                                               batch_size=batch_size, 
                                               target_size=(image_size, image_size), 
                                               color_mode=color_mode)
elif algorithm == 'ke_aug':
    test_gen, test_generator = mu.my_generator(test_path, 
                                               rescale=rescale,
                                               horizontal_flip=horizontal_flip,
                                               vertical_flip=vertical_flip,
                                               width_shift_range=width_shift_range,
                                               height_shift_range=height_shift_range,
                                               rotation_range=rotation_range,
                                               shear_range=shear_range,
                                               zoom_range=zoom_range,
                                               channel_shift_range=channel_shift_range,
                                               shuffle=shuffle,
                                               batch_size=batch_size, 
                                               color_mode=color_mode, 
                                               target_size=(image_size, image_size))
    
prediction = em.get_prediction_by_pre_trained_model(model, 
                                                    test_generator, 
                                                    dataset_path=test_path,
                                                    gen=test_gen, 
                                                    batch_process=32,
                                                    num_classes=100,
                                                    show_first_fig=False,
                                                    color_mode=color_mode, 
                                                    rescale=rescale, 
                                                    augment_size=augment_size,
                                                    target_size=(image_size, image_size), 
                                                    algorithm=algorithm)
print('OK!')
# Out:
# Found 4000 images belonging to 100 classes.
# OK!

# %% [markdown]
# ## 7.4 获取top-k的结果并写入文件

# %%
topk_indices = em.get_topk_indices_by_single_generator(test_generator, 
                                                       prediction=prediction, 
                                                       k=k)
results = cu.get_topk_pd_data(test_generator, 
                         class_indices, 
                         topk_indices=topk_indices)
cu.write_pd_data_into_csv(results, 
                          'results/VGG16/top{}_results_VGG16.csv'.format(k), 
                          have_chinese=True, 
                          index=None, 
                          header=True)
print('OK!')
# Out:
# OK!

# %% [markdown]
# ## 7.5 获取top-1的结果并写入文件

# %%
top1_results = cu.get_top1_pd_data_from_topk('results/VGG16/top{}_results_VGG16.csv'.format(k), 
                                             'results/VGG16/top1_results_VGG16.csv')
cu.write_pd_data_into_csv(top1_results, 
                          'results/VGG16/top1_results_VGG16.csv', 
                          have_chinese=True, 
                          index=None, 
                          header=True)
print('OK!')
# Out:
# OK!
