# %%
from recognition import model_utils as mu
from recognition import train_model as tm
from recognition import evaluate_model as em
from recognition import csv_utils as cu


# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# global variables
BATCH_SIZE = 64 # batch size
IMAGE_SIZE = 160 # image size
COLOR_MODE = 'grayscale' # color mode 
RESCALE = 1./255

# %%
train_generator = mu.my_generator('datasets/all_train', 
                                  rescale=RESCALE,
                                  horizontal_flip=False,
                                  vertical_flip=False,
                                  rotation_range=10,
                                  width_shift_range=0.1,
                                  height_shift_range=0.1,
                                  zoom_range=0.1,
                                  shuffle=True,
                                  batch_size=BATCH_SIZE, 
                                  color_mode=COLOR_MODE, 
                                  target_size=(IMAGE_SIZE, IMAGE_SIZE))

valid_generator = mu.my_generator('datasets/validation', 
                                  rescale=RESCALE,
                                  shuffle=True,
                                  batch_size=BATCH_SIZE, 
                                  color_mode=COLOR_MODE, 
                                  target_size=(IMAGE_SIZE, IMAGE_SIZE))

print('Writing the class_indices into csv file.')
cu.write_list_or_dict_into_csv(train_generator.class_indices, csv_path='class_indices.csv', have_chinese=False)
print('OK!')
# Out:
# Found 39987 images belonging to 100 classes.
# Found 3807 images belonging to 100 classes.
# Writing the class_indices into csv file.
# OK!

# %% [markdown]
# # InceptionV3

# %%
from keras.applications.inception_v3 import InceptionV3
from keras.layers import BatchNormalization, Activation, Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, PReLU, GlobalAveragePooling2D
from keras.models import Model
from keras.regularizers import l2


def build_model_based_on_inceptionv3(out_dims, base_weights=None, 
                                     input_shape=(299, 299, 3), weights=None):
    """
    Input:
      - fea_dims: 
      - out_dims:
      
    Return:
       - model: 
    """
    inceptionv3_base_model = InceptionV3(weights=base_weights, 
                                         include_top=False, 
                                         input_shape=input_shape)
    x = inceptionv3_base_model.output
    
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = PReLU()(x)
    # x = Dropout(0.7)(x)
    
    x = Dense(512)(x)
    x = BatchNormalization()(x)
    x = PReLU()(x)
    x = Dropout(0.4)(x)
    
    x = Dense(out_dims, kernel_regularizer=l2(0.01))(x)
    x = Activation('softmax')(x)
    model = Model(inputs=inceptionv3_base_model.input, outputs=x)
    
    if weights:
        model.load_weights(weights, by_name=False)

    return model

mu.clear_session()

channels = mu.get_channels(COLOR_MODE)
if channels is 1:
    base_weights = None
else:
    base_weights = 'imagenet'
    
model = build_model_based_on_inceptionv3(100, 
                                         base_weights=base_weights, 
                                         input_shape=(IMAGE_SIZE, IMAGE_SIZE, channels), 
                                         weights='models/InceptionV3/model11.h5')
for index, layer in enumerate(model.layers):
    print(index, layer.name)
    
print('\n The architecture of the model:')
model.summary()
# Out:
# 0 input_1
# 1 conv2d_1
# 2 batch_normalization_1
# 3 activation_1
# 4 conv2d_2
# 5 batch_normalization_2
# 6 activation_2
# 7 conv2d_3
# 8 batch_normalization_3
# 9 activation_3
# 10 max_pooling2d_1
# 11 conv2d_4
# 12 batch_normalization_4
# 13 activation_4
# 14 conv2d_5
# 15 batch_normalization_5
# 16 activation_5
# 17 max_pooling2d_2
# 18 conv2d_9
# 19 batch_normalization_9
# 20 activation_9
# 21 conv2d_7
# 22 conv2d_10
# 23 batch_normalization_7
# 24 batch_normalization_10
# 25 activation_7
# 26 activation_10
# 27 average_pooling2d_1
# 28 conv2d_6
# 29 conv2d_8
# 30 conv2d_11
# 31 conv2d_12
# 32 batch_normalization_6
# 33 batch_normalization_8
# 34 batch_normalization_11
# 35 batch_normalization_12
# 36 activation_6
# 37 activation_8
# 38 activation_11
# 39 activation_12
# 40 mixed0
# 41 conv2d_16
# 42 batch_normalization_16
# 43 activation_16
# 44 conv2d_14
# 45 conv2d_17
# 46 batch_normalization_14
# 47 batch_normalization_17
# 48 activation_14
# 49 activation_17
# ...

# %%
freeze_range = range(0, 0)
model = mu.freeze_layers(model, freeze_range)
mu.count_parameters(model)
# Out:
# Total params: 11,390,404
# Trainable params: 11,365,444
# Non-trainable params: 24,960

# %%
LEARNING_RATE = 0.0000001
DECAY = 1e-2
EPOCHS = 10

model_path = 'models/InceptionV3/model12.h5'
history = tm.train_model(model,
                         train_generator, 
                         valid_generator,
                         model_path=model_path,
                         print_lr=False,
                         automatic_reduction=True,
                         patience=1,
                         reduce_factor=0.1,
                         reduce_time=8,
                         reduce_monitor='val_acc',
                         save_best='val_loss',
                         batch_size=BATCH_SIZE,
                         learning_rate=LEARNING_RATE,
                         decay=DECAY,
                         epochs=EPOCHS)
# Out:
# Epoch 1/10
# 625/625 [==============================] - 315s 504ms/step - loss: 0.0773 - acc: 0.9910 - val_loss: 0.1623 - val_acc: 0.9687
# Epoch 2/10
# 625/625 [==============================] - 308s 493ms/step - loss: 0.0758 - acc: 0.9917 - val_loss: 0.1618 - val_acc: 0.9690
# Epoch 3/10
# 625/625 [==============================] - 308s 493ms/step - loss: 0.0769 - acc: 0.9913 - val_loss: 0.1619 - val_acc: 0.9685
# Epoch 4/10
# 625/625 [==============================] - 309s 494ms/step - loss: 0.0753 - acc: 0.9920 - val_loss: 0.1625 - val_acc: 0.9690
# Epoch 5/10
# 625/625 [==============================] - 308s 493ms/step - loss: 0.0752 - acc: 0.9921 - val_loss: 0.1626 - val_acc: 0.9693
# Epoch 6/10
# 625/625 [==============================] - 307s 492ms/step - loss: 0.0783 - acc: 0.9916 - val_loss: 0.1621 - val_acc: 0.9693
# Epoch 7/10
# 625/625 [==============================] - 306s 489ms/step - loss: 0.0772 - acc: 0.9920 - val_loss: 0.1622 - val_acc: 0.9690
# Epoch 8/10
# ...

# %% [markdown]
# # Draw history curve

# %%
mu.draw_plot(history)

# %% [markdown]
# # Evaluate the performance of our model

# %% [markdown]
# ### Load model

# %%
model = mu.load_my_model('models/InceptionV3/model11.h5')

# %% [markdown]
# ### Get the mapping from classes to indices

# %%
class_indices = cu.get_class_indices('class_indices.csv')
print(class_indices)
# Out:
# {'且': 0, '世': 1, '东': 2, '九': 3, '亭': 4, '今': 5, '从': 6, '令': 7, '作': 8, '使': 9, '侯': 10, '元': 11, '光': 12, '利': 13, '印': 14, '去': 15, '受': 16, '右': 17, '司': 18, '合': 19, '名': 20, '周': 21, '命': 22, '和': 23, '唯': 24, '堂': 25, '士': 26, '多': 27, '夜': 28, '奉': 29, '女': 30, '好': 31, '始': 32, '字': 33, '孝': 34, '守': 35, '宗': 36, '官': 37, '定': 38, '宜': 39, '室': 40, '家': 41, '寒': 42, '左': 43, '常': 44, '建': 45, '徐': 46, '御': 47, '必': 48, '思': 49, '意': 50, '我': 51, '敬': 52, '新': 53, '易': 54, '春': 55, '更': 56, '朝': 57, '李': 58, '来': 59, '林': 60, '正': 61, '武': 62, '氏': 63, '永': 64, '流': 65, '海': 66, '深': 67, '清': 68, '游': 69, '父': 70, '物': 71, '玉': 72, '用': 73, '申': 74, '白': 75, '皇': 76, '益': 77, '福': 78, '秋': 79, '立': 80, '章': 81, '老': 82, '臣': 83, '良': 84, '莫': 85, '虎': 86, '衣': 87, '西': 88, '起': 89, '足': 90, '身': 91, '通': 92, '遂': 93, '重': 94, '陵': 95, '雨': 96, '高': 97, '黄': 98, '鼎': 99}

# %% [markdown]
# ### Get the prediction for the validation set

# %%
generator = mu.my_generator('datasets/validation',
                             shuffle=False,
                             rescale=RESCALE, 
                             batch_size=BATCH_SIZE, 
                             target_size=(IMAGE_SIZE, IMAGE_SIZE), 
                             color_mode=COLOR_MODE)


use_augment = False
if use_augment:
    prediction = em.predict_by_augment_patches(model,
                                               'datasets/validation',
                                               generator, 
                                               batch_size=32, 
                                               num_classes=100,
                                               show_first_fig=False,
                                               rescale=RESCALE,
                                               color_mode=COLOR_MODE, 
                                               target_size=(IMAGE_SIZE, IMAGE_SIZE))
else:
    prediction = em.get_prediction_by_single_generator(model, generator)
print('OK!')
# Out:
# Found 3807 images belonging to 100 classes.
# OK!

# %% [markdown]
# ### Evaluate the model

# %%
output = {}
print('Use data augmentation: {}'.format(use_augment))
for k in [1, 5]:
    output[str(k)] = em.evaluate_topk_accuracy_by_single_generator(generator, 
                                                                   class_indices,
                                                                   prediction=prediction, 
                                                                   k=k)
# Out:
# Use data augmentation: False
# Top-1 accuracy: 95.43%
# Top-5 accuracy: 98.32%

# %% [markdown]
# ### Check the wrong information

# %%
correct_number, total_number, topk_indices, topk_classes, wrong_info = output[str(1)]
for info in wrong_info:
    print(info)

# %% [markdown]
# ### Visualize the wrong images

# %%
from recognition import image_utils as iu

iu.show_images_in_wrong_info(wrong_info, 'train', number=20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-c16232f75cfd> in <module>()
#       1 from recognition import image_utils as iu
#       2
# ----> 3 iu.show_images_in_wrong_info(wrong_info, 'train', number=20)
#
# NameError: name 'wrong_info' is not defined

# %% [markdown]
# # Write answer in the csv file

# %%
test_generator = mu.my_generator('datasets/test',
                                 shuffle=False,
                                 rescale=RESCALE, 
                                 batch_size=BATCH_SIZE, 
                                 target_size=(IMAGE_SIZE, IMAGE_SIZE), 
                                 color_mode=COLOR_MODE)

use_augment = True

if use_augment:
    prediction = em.predict_by_augment_patches(model,
                                               'datasets/test',
                                               test_generator, 
                                               batch_size=32, 
                                               num_classes=100,
                                               show_first_fig=False,
                                               rescale=RESCALE,
                                               color_mode=COLOR_MODE, 
                                               target_size=(IMAGE_SIZE, IMAGE_SIZE))
else:
    prediction = em.get_prediction_by_single_generator(model, test_generator)
    
topk_indices = em.get_topk_indices_by_single_generator(test_generator, 
                                                       prediction=prediction, 
                                                       k=5)

results = cu.get_pd_data(test_generator, class_indices, topk_indices=topk_indices)
cu.write_pd_data_into_csv(results, 'results/InceptionV3/results_InceptionV3.csv', 
                          have_chinese=True, index=None, header=True)
print('OK!')
# Out:
# Found 10000 images belonging to 1 classes.
# OK!

# %% [markdown]
# # Get and write top1 answer into csv file

# %%
top1_results = cu.get_top1_pd_data_from_topk('results/InceptionV3/results_InceptionV3.csv', 
                                             'results/InceptionV3/top1_results_InceptionV3.csv')
cu.write_pd_data_into_csv(results, 'results/InceptionV3/top1_results_InceptionV3.csv', 
                          have_chinese=True, index=None, header=True)
print('OK!')
# Out:
# OK!
